# %%
# !pip install AmbuView==0.1.3
# Out:
# Requirement already satisfied: AmbuView==0.1.2 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (0.1.2)
# Requirement already satisfied: numpy==1.26.3 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (1.26.3)
# Requirement already satisfied: osmnx==1.8.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (1.8.1)
# Requirement already satisfied: networkx==3.2.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (3.2.1)
# Requirement already satisfied: folium==0.15.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (0.15.1)
# Requirement already satisfied: alphashape==1.3.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (1.3.1)
# Requirement already satisfied: requests==2.31.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (2.31.0)
# Requirement already satisfied: pandas==2.1.4 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (2.1.4)
# Requirement already satisfied: geopandas==0.14.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (0.14.1)
# Requirement already satisfied: shapely==2.0.2 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (2.0.2)
# Requirement already satisfied: scipy==1.11.4 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (1.11.4)
# Requirement already satisfied: setuptools==60.2.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (60.2.0)
# Requirement already satisfied: scikit-learn==1.3.2 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (1.3.2)
# Requirement already satisfied: geopy==2.4.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from AmbuView==0.1.2) (2.4.1)
# Requirement already satisfied: Click>=6.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from alphashape==1.3.1->AmbuView==0.1.2) (8.0.4)
# Requirement already satisfied: click-log>=0.3.2 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from alphashape==1.3.1->AmbuView==0.1.2) (0.4.0)
# Requirement already satisfied: trimesh>=3.9.8 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from alphashape==1.3.1->AmbuView==0.1.2) (4.0.8)
# Requirement already satisfied: rtree>=0.9.7 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from alphashape==1.3.1->AmbuView==0.1.2) (1.0.1)
# Requirement already satisfied: branca>=0.6.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from folium==0.15.1->AmbuView==0.1.2) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from folium==0.15.1->AmbuView==0.1.2) (3.1.2)
# Requirement already satisfied: xyzservices in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from folium==0.15.1->AmbuView==0.1.2) (2022.9.0)
# Requirement already satisfied: fiona>=1.8.21 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from geopandas==0.14.1->AmbuView==0.1.2) (1.9.5)
# Requirement already satisfied: packaging in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from geopandas==0.14.1->AmbuView==0.1.2) (23.0)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from geopandas==0.14.1->AmbuView==0.1.2) (3.6.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from geopy==2.4.1->AmbuView==0.1.2) (2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from pandas==2.1.4->AmbuView==0.1.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from pandas==2.1.4->AmbuView==0.1.2) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from pandas==2.1.4->AmbuView==0.1.2) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from requests==2.31.0->AmbuView==0.1.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from requests==2.31.0->AmbuView==0.1.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from requests==2.31.0->AmbuView==0.1.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from requests==2.31.0->AmbuView==0.1.2) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.3.2->AmbuView==0.1.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.3.2->AmbuView==0.1.2) (2.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas==0.14.1->AmbuView==0.1.2) (22.1.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas==0.14.1->AmbuView==0.1.2) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas==0.14.1->AmbuView==0.1.2) (0.7.2)
# Requirement already satisfied: six in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas==0.14.1->AmbuView==0.1.2) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thomasowen/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium==0.15.1->AmbuView==0.1.2) (2.1.1)

# %%
from AmbuView import Full_Graph_Generation
import os
import sys

# %%
# test data for torbay with a single population density, single location, and limited to regional ambulance hubs
Full_Graph_Generation.create_ambulance_coverage_map(locations_csv='test_data_torquay_locations.csv',
                                  uk_county_boundary_url="https://services1.arcgis.com/ESMARspQHYMw9BZ9/arcgis/rest/services/Counties_May_2023_Boundaries_EN_BFC/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson",
                                  pop_density_urls=[
                                      "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E06000027.json"
                                  ],
                                  pop_density_csv="Torbay_test_data_population_density.csv",
                                  ambulance_hub_lat_lon_tuples= [(50.38872, -3.51266),(50.442964, -3.586598),(50.482712,-3.55166)],
                                  ambulance_time=15)
# Out:
# Generating map...
# Downloading URL Data
# The number of ambulance hub isochrones to be added: 3
# Loading...
# Processing isochrones...
# Number of isochrones added: 1
# Number of isochrones added: 2
# Number of isochrones added: 3
# centroid location =  [50.438132 -3.550306]
# Running new hub optimization algorithm...
# The furthest point within the convex hull from all central nodes is at: [50.46189937 -3.52530057]
# the total isochrones generated: 3
# Total Runtime: 6.584326267242432 seconds
# The map can be found as an HTML file located in the same directory as where you ran the python script named:combined_isochrone_map.HTML

# %%
# Test data changing the ambulance time to 5 minutes
Full_Graph_Generation.create_ambulance_coverage_map(locations_csv='Devon_2021_Census_Population_by_town.csv',
                                  uk_county_boundary_url="https://services1.arcgis.com/ESMARspQHYMw9BZ9/arcgis/rest/services/Counties_May_2023_Boundaries_EN_BFC/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson",
                                  pop_density_urls=[
                                      "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E07000046.json",
            "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E07000040.json",
            "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E07000041.json",
            "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E07000042.json",
            "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E07000043.json",
            "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E07000044.json",
            "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E07000045.json",
            "https://raw.githubusercontent.com/martinjc/UK-GeoJSON/master/json/statistical/eng/msoa_by_lad/E07000047.json"
                                  ],
                                  pop_density_csv="nomis_2023_12_31_000343.csv",
                                  ambulance_hub_lat_lon_tuples= [(50.38872, -3.51266),(50.442964, -3.586598),(50.482712,-3.55166)],
                                  ambulance_time=5)
# Out:
# Generating map...
# Downloading URL Data
# The number of ambulance hub isochrones to be added: 3
# Loading...
# Processing isochrones...
# Number of isochrones added: 4
# Number of isochrones added: 5
# Number of isochrones added: 6
# centroid location =  [50.438132 -3.550306]
# Running new hub optimization algorithm...
# The furthest point within the convex hull from all central nodes is at: [50.482712 -3.586598]
# the total isochrones generated: 6
# Total Runtime: 8.702088832855225 seconds
# The map can be found as an HTML file located in the same directory as where you ran the python script named:combined_isochrone_map.HTML
