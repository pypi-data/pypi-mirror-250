# %%
import numpy as np
from shapely import MultiPoint
from scipy.optimize import minimize
from AmbuView import distance_calculations, optimization, map_visualization
import folium

# %%
# Testing optimization module
optimization.maximize_distance_within_convex_hull([(50.38872, -3.51266),(50.442964, -3.586598),(50.482712,-3.55166)],
                                     [(50.3951, -3.5),(50.4351, -3.5642), (50.4619, -3.5253)])
# expected output: array containing optimal point (array([50.46189937, -3.52530057]))
# Out:
# centroid location =  [50.438132 -3.550306]
# Running new hub optimization algorithm...
# array([50.46189937, -3.52530057])

# %%
f_map = folium.Map(location=[50.38872, -3.51266], zoom_start=11)
optimization.add_marker_for_furthest_point(f_map, [(50.38872, -3.51266),(50.442964, -3.586598),(50.482712,-3.55166)],
                                     [(50.3951, -3.5),(50.4351, -3.5642), (50.4619, -3.5253)])
map_visualization.add_ambulance_hub_markers(f_map, [(50.38872, -3.51266),(50.442964, -3.586598),(50.482712,-3.55166)])
map_visualization.add_heatmap_layer(f_map,[(50.3951, -3.5, 17834), (50.4351, -3.5642, 67488), (50.4619, -3.5253, 52037)])
f_map # Expected output: folium map with optimal point in green.
# Out:
# centroid location =  [50.438132 -3.550306]
# Running new hub optimization algorithm...
# The furthest point within the convex hull from all central nodes is at: [50.46189937 -3.52530057]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_851177d2940a47353c092b28317096f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_851177d2940a47353c092b28317096f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_851177d2940a47353c092b28317096f8 = L.map(
#                 &quot;map_851177d2940a47353c092b28317096f8&quot;,
#                 {
#                     center: [50.38872, -3.51266],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2f7454d23f8c961e1b4604dc52765aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b2f7454d23f8c961e1b4604dc52765aa.addTo(map_851177d2940a47353c092b28317096f8);
#
#
#             var marker_0ad7c45a77f6fcc9db6e9a116f1aa1a8 = L.marker(
#                 [50.46189936573857, -3.5253005746523014],
#                 {}
#             ).addTo(map_851177d2940a47353c092b28317096f8);
#
#
#             var icon_98355c8c9e3a39d1dea07327d08512db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0ad7c45a77f6fcc9db6e9a116f1aa1a8.setIcon(icon_98355c8c9e3a39d1dea07327d08512db);
#
#
#         var popup_a9b2329e11a3feb594547185690e7596 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13ae6dd8b714f01410b8854874af93d3 = $(`&lt;div id=&quot;html_13ae6dd8b714f01410b8854874af93d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Furthest Point within Convex Hull from Central Nodes&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_a9b2329e11a3feb594547185690e7596.setContent(html_13ae6dd8b714f01410b8854874af93d3);
#
#
#
#         marker_0ad7c45a77f6fcc9db6e9a116f1aa1a8.bindPopup(popup_a9b2329e11a3feb594547185690e7596)
#         ;
#
#
#
#
#             var marker_0094937de81561dbc4cd120bf7252a44 = L.marker(
#                 [50.38872, -3.51266],
#                 {}
#             ).addTo(map_851177d2940a47353c092b28317096f8);
#
#
#             var icon_e60bd2b5d0d7132292d8c594a53e088f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ambulance&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0094937de81561dbc4cd120bf7252a44.setIcon(icon_e60bd2b5d0d7132292d8c594a53e088f);
#
#
#         var popup_e68fa238016a5aa949cd2b25d14bd05a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe2b27e42600e7a50e8ff6d9564e1cf3 = $(`&lt;div id=&quot;html_fe2b27e42600e7a50e8ff6d9564e1cf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ambulance Hub&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_e68fa238016a5aa949cd2b25d14bd05a.setContent(html_fe2b27e42600e7a50e8ff6d9564e1cf3);
#
#
#
#         marker_0094937de81561dbc4cd120bf7252a44.bindPopup(popup_e68fa238016a5aa949cd2b25d14bd05a)
#         ;
#
#
#
#
#             var marker_ae361f29f986bf50b70129569afec47d = L.marker(
#                 [50.442964, -3.586598],
#                 {}
#             ).addTo(map_851177d2940a47353c092b28317096f8);
#
#
#             var icon_913f56e374cd3ab54cc90da69b1c86e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ambulance&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ae361f29f986bf50b70129569afec47d.setIcon(icon_913f56e374cd3ab54cc90da69b1c86e8);
#
#
#         var popup_f88bea93518552f4d4c5b13a03face77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_631f8f74cf2c8fc2b01f08799f45e0ae = $(`&lt;div id=&quot;html_631f8f74cf2c8fc2b01f08799f45e0ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ambulance Hub&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_f88bea93518552f4d4c5b13a03face77.setContent(html_631f8f74cf2c8fc2b01f08799f45e0ae);
#
#
#
#         marker_ae361f29f986bf50b70129569afec47d.bindPopup(popup_f88bea93518552f4d4c5b13a03face77)
#         ;
#
#
#
#
#             var marker_0b31b75adb680eeb252ab816972917a4 = L.marker(
#                 [50.482712, -3.55166],
#                 {}
#             ).addTo(map_851177d2940a47353c092b28317096f8);
