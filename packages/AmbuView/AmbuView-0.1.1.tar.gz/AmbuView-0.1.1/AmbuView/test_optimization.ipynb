# %%
import numpy as np
from shapely import MultiPoint
from scipy.optimize import minimize
from AmbuView import distance_calculations, optimization, map_visualization
import folium

# %%
# Testing optimization module
optimization.maximize_distance_within_convex_hull([(50.38872, -3.51266),(50.442964, -3.586598),(50.482712,-3.55166)],
                                     [(50.3951, -3.5),(50.4351, -3.5642), (50.4619, -3.5253)])
# expected output: array containing optimal point (array([50.46189937, -3.52530057]))
# Out:
# centroid location =  [50.438132 -3.550306]
# Running new hub optimization algorithm...
# array([50.46189937, -3.52530057])

# %%
f_map = folium.Map(location=[50.38872, -3.51266], zoom_start=11)
optimization.add_marker_for_furthest_point(f_map, [(50.38872, -3.51266),(50.442964, -3.586598),(50.482712,-3.55166)],
                                     [(50.3951, -3.5),(50.4351, -3.5642), (50.4619, -3.5253)])
map_visualization.add_ambulance_hub_markers(f_map, [(50.38872, -3.51266),(50.442964, -3.586598),(50.482712,-3.55166)])
map_visualization.add_heatmap_layer(f_map,[(50.3951, -3.5, 17834), (50.4351, -3.5642, 67488), (50.4619, -3.5253, 52037)])
f_map # Expected output: folium map with optimal point in green.
# Out:
# centroid location =  [50.438132 -3.550306]
# Running new hub optimization algorithm...
# The furthest point within the convex hull from all central nodes is at: [50.46189937 -3.52530057]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f6e03c08319485ee826bc0f2fefa9ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f6e03c08319485ee826bc0f2fefa9ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f6e03c08319485ee826bc0f2fefa9ab = L.map(
#                 &quot;map_1f6e03c08319485ee826bc0f2fefa9ab&quot;,
#                 {
#                     center: [50.38872, -3.51266],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_239366cc0238ead0aef9563fd98a581f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_239366cc0238ead0aef9563fd98a581f.addTo(map_1f6e03c08319485ee826bc0f2fefa9ab);
#
#
#             var marker_24280e34cf4877caf2f7dee0b9fc85db = L.marker(
#                 [50.46189936573857, -3.5253005746523014],
#                 {}
#             ).addTo(map_1f6e03c08319485ee826bc0f2fefa9ab);
#
#
#             var icon_e00d0946b5d1f09f144740e45c5b07e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_24280e34cf4877caf2f7dee0b9fc85db.setIcon(icon_e00d0946b5d1f09f144740e45c5b07e6);
#
#
#         var popup_03df11fd46e5b7fbd7505e7e8fd38c1f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2709a8f2655b41234f421ba1deb09050 = $(`&lt;div id=&quot;html_2709a8f2655b41234f421ba1deb09050&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Furthest Point within Convex Hull from Central Nodes&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_03df11fd46e5b7fbd7505e7e8fd38c1f.setContent(html_2709a8f2655b41234f421ba1deb09050);
#
#
#
#         marker_24280e34cf4877caf2f7dee0b9fc85db.bindPopup(popup_03df11fd46e5b7fbd7505e7e8fd38c1f)
#         ;
#
#
#
#
#             var marker_c41bc2c783c6f7ce097edbcc550410af = L.marker(
#                 [50.38872, -3.51266],
#                 {}
#             ).addTo(map_1f6e03c08319485ee826bc0f2fefa9ab);
#
#
#             var icon_cbaf19677bb7ab41c1de7c07cbc7597b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ambulance&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c41bc2c783c6f7ce097edbcc550410af.setIcon(icon_cbaf19677bb7ab41c1de7c07cbc7597b);
#
#
#         var popup_9f17550260aada9ce61783d5b955082a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9c979ded31dec1d5dcfc2bb8b59a066 = $(`&lt;div id=&quot;html_b9c979ded31dec1d5dcfc2bb8b59a066&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ambulance Hub&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_9f17550260aada9ce61783d5b955082a.setContent(html_b9c979ded31dec1d5dcfc2bb8b59a066);
#
#
#
#         marker_c41bc2c783c6f7ce097edbcc550410af.bindPopup(popup_9f17550260aada9ce61783d5b955082a)
#         ;
#
#
#
#
#             var marker_b1b9769e9f548ea6e62d308990f6e1ae = L.marker(
#                 [50.442964, -3.586598],
#                 {}
#             ).addTo(map_1f6e03c08319485ee826bc0f2fefa9ab);
#
#
#             var icon_3970db101f60a0767b32ceae677c3378 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ambulance&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b1b9769e9f548ea6e62d308990f6e1ae.setIcon(icon_3970db101f60a0767b32ceae677c3378);
#
#
#         var popup_d559cd697252d9e257b632bcbad7cd4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d631eb7d39360e5cf9e8f32f7c7c241 = $(`&lt;div id=&quot;html_3d631eb7d39360e5cf9e8f32f7c7c241&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ambulance Hub&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_d559cd697252d9e257b632bcbad7cd4a.setContent(html_3d631eb7d39360e5cf9e8f32f7c7c241);
#
#
#
#         marker_b1b9769e9f548ea6e62d308990f6e1ae.bindPopup(popup_d559cd697252d9e257b632bcbad7cd4a)
#         ;
#
#
#
#
#             var marker_282844b60bbcd119567f68e6cb262af4 = L.marker(
#                 [50.482712, -3.55166],
#                 {}
#             ).addTo(map_1f6e03c08319485ee826bc0f2fefa9ab);
